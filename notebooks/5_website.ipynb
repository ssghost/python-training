# %% [markdown]
# # Accessing data from a website
# Not all websites make it easy to grab data. Luckily, `pandas` can help.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

result = requests.get('https://en.wikipedia.org/wiki/List_of_sovereign_states')
pd.read_html(result.content)[0].head(20)
# Out:
#                               Common and formal names  \
# 0                                                 NaN
# 1   UN member states and General Assembly observer...
# 2                     Abkhazia → See Abkhazia listing
# 3                                         Afghanistan
# 4                       Albania – Republic of Albania
# 5   Algeria – People's Democratic Republic of Algeria
# 6                   Andorra – Principality of Andorra
# 7                         Angola – Republic of Angola
# 8                                 Antigua and Barbuda
# 9                   Argentina – Argentine Republic[i]
# 10                      Armenia – Republic of Armenia
# 11                      Artsakh → See Artsakh listing
# 12              Australia – Commonwealth of Australia
# 13                      Austria – Republic of Austria
# 14                Azerbaijan – Republic of Azerbaijan
# 15     Bahamas, The – Commonwealth of The Bahamas[14]
# 16                       Bahrain – Kingdom of Bahrain
# 17       Bangladesh – People's Republic of Bangladesh
# 18                                           Barbados
# 19                      Belarus – Republic of Belarus
#
#    Membership within the UN System[c]           Sovereignty dispute[d]  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2     Abkhazia → See Abkhazia listing  Abkhazia → See Abkhazia listing
# 3                     UN member state                              NaN
# 4                                 NaN                              NaN
# 5                                 NaN                              NaN
# 6                                 NaN                              NaN
# 7                                 NaN                              NaN
# 8                                 NaN                              NaN
# 9                                 NaN                              NaN
# 10                                NaN      Not recognized by Pakistan.
# 11      Artsakh → See Artsakh listing    Artsakh → See Artsakh listing
# 12                                NaN                              NaN
# 13                                NaN                              NaN
# 14                                NaN                              NaN
# 15                                NaN                              NaN
# 16                                NaN                              NaN
# 17                                NaN                              NaN
# 18                                NaN                              NaN
# 19                                NaN                              NaN
#
#    Further information on status and recognition of sovereignty[f]
# 0                                                 NaN
# 1                                                 NaN
# 2                     Abkhazia → See Abkhazia listing
# 3   The de facto ruling government, the Islamic Em...
# 4                                                 NaN
# 5                                                 NaN
# 6   Andorra is a co-principality in which the offi...
# 7                                                 NaN
# 8   Antigua and Barbuda is a Commonwealth realm[g]...
# 9   Argentina is a federation of 23 provinces and ...
# 10  Armenia is not recognized by Pakistan due to t...
# 11                      Artsakh → See Artsakh listing
# 12  Australia is a Commonwealth realm[g] and a fed...
# 13  Member of the European Union.[e] Austria is a ...
# 14  Azerbaijan contains one autonomous region, Nak...
# 15            The Bahamas is a Commonwealth realm.[g]
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Many states rescinded their recognition of Pre...

# %% [markdown]
# For more complex parsing, we can utilize the `BeautifulSoup` library. Let's try to extract the same table, but use the new library.

# %%
soup = BeautifulSoup(result.content, 'lxml') # Parse the HTML as a string
str(soup)[:500]
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-page-tools-enabled" dir="l'

# %% [markdown]
# Find the tables.

# %%
tables = soup.find_all('table')

# %% [markdown]
# Using the `read_html` function of `pandas`, read the first table into a dataframe.

# %%
pd.read_html(str(tables[0]))[0].head(20)
# Out:
#                               Common and formal names  \
# 0                                                 NaN
# 1   UN member states and General Assembly observer...
# 2                     Abkhazia → See Abkhazia listing
# 3                                         Afghanistan
# 4                       Albania – Republic of Albania
# 5   Algeria – People's Democratic Republic of Algeria
# 6                   Andorra – Principality of Andorra
# 7                         Angola – Republic of Angola
# 8                                 Antigua and Barbuda
# 9                   Argentina – Argentine Republic[i]
# 10                      Armenia – Republic of Armenia
# 11                      Artsakh → See Artsakh listing
# 12              Australia – Commonwealth of Australia
# 13                      Austria – Republic of Austria
# 14                Azerbaijan – Republic of Azerbaijan
# 15     Bahamas, The – Commonwealth of The Bahamas[14]
# 16                       Bahrain – Kingdom of Bahrain
# 17       Bangladesh – People's Republic of Bangladesh
# 18                                           Barbados
# 19                      Belarus – Republic of Belarus
#
#    Membership within the UN System[c]           Sovereignty dispute[d]  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2     Abkhazia → See Abkhazia listing  Abkhazia → See Abkhazia listing
# 3                     UN member state                              NaN
# 4                                 NaN                              NaN
# 5                                 NaN                              NaN
# 6                                 NaN                              NaN
# 7                                 NaN                              NaN
# 8                                 NaN                              NaN
# 9                                 NaN                              NaN
# 10                                NaN      Not recognized by Pakistan.
# 11      Artsakh → See Artsakh listing    Artsakh → See Artsakh listing
# 12                                NaN                              NaN
# 13                                NaN                              NaN
# 14                                NaN                              NaN
# 15                                NaN                              NaN
# 16                                NaN                              NaN
# 17                                NaN                              NaN
# 18                                NaN                              NaN
# 19                                NaN                              NaN
#
#    Further information on status and recognition of sovereignty[f]
# 0                                                 NaN
# 1                                                 NaN
# 2                     Abkhazia → See Abkhazia listing
# 3   The de facto ruling government, the Islamic Em...
# 4                                                 NaN
# 5                                                 NaN
# 6   Andorra is a co-principality in which the offi...
# 7                                                 NaN
# 8   Antigua and Barbuda is a Commonwealth realm[g]...
# 9   Argentina is a federation of 23 provinces and ...
# 10  Armenia is not recognized by Pakistan due to t...
# 11                      Artsakh → See Artsakh listing
# 12  Australia is a Commonwealth realm[g] and a fed...
# 13  Member of the European Union.[e] Austria is a ...
# 14  Azerbaijan contains one autonomous region, Nak...
# 15            The Bahamas is a Commonwealth realm.[g]
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Many states rescinded their recognition of Pre...

# %% [markdown]
# As we can see, the data we get back isn't always perfect, which is what's so nice about APIs instead of parsing HTML. Nevertheless, we would benefit a lot if we simplified this into a function.

# %%
def dfFromURL(url, tableNumber=1):
    soup = BeautifulSoup(requests.get(url).content, 'lxml') # Parse the HTML as a string
    tables = soup.find_all('table')
    # check table number is within number of tables on the page
    assert len(tables) >= tableNumber
    return pd.read_html(str(tables[tableNumber-1]))[0]

# %% [markdown]
# Now we can make a pretty simple call to get an HTML table as a dataframe. Let's try it.

# %%
prices = dfFromURL('https://finance.yahoo.com/quote/JPM/history?p=JPM')
prices.head()
# Out:
#                                                    0
# 0  Will be right back... Thank you for your patie...

# %% [markdown]
# Got some messy data hear with divs and some disclaimers on the bottom...let's clean it up with a simple `dropna`.

# %%
prices = prices.dropna()
prices.head()
# Out:
#                                                    0
# 0  Will be right back... Thank you for your patie...

# %% [markdown]
# Cool! Let's try to get the second table from a website. Let's see what the Cavs record was for the last few seasons:

# %%
df1 = dfFromURL('https://www.espn.com/nba/team/stats/_/name/cle', 0)
df1
# Out:
#      FGM   FGA   FG%   3PM   3PA   3P%   FTM   FTA    FT%   2PM   2PA    2P%  \
# 0   10.0  20.6  48.4   3.6   9.3  38.6   4.7   5.4   86.7   6.4  11.3   56.6
# 1    7.6  16.4  46.2   2.4   6.0  41.0   4.0   4.7   86.3   5.1  10.4   49.2
# 2    6.7  12.1  55.5   0.3   1.3  21.6   2.6   3.9   67.4   6.4  10.7   59.7
# 3    6.0   9.3  64.5   0.0   0.1  11.1   2.4   3.3   73.3   6.0   9.1   65.3
# 4    4.3  10.0  43.1   1.7   4.4  39.2   1.8   2.4   72.2   2.6   5.6   46.2
# 5    3.1   6.9  45.2   1.5   4.1  37.3   1.0   1.4   69.5   1.6   2.8   56.5
# 6    2.7   7.0  38.9   1.7   4.8  35.4   1.4   1.5   88.9   1.0   2.2   46.7
# 7    2.3   4.7  49.4   0.8   2.3  36.3   1.0   1.4   75.7   1.5   2.4   61.7
# 8    2.0   3.7  53.8   1.4   2.7  52.6   0.1   0.1  100.0   0.6   1.0   57.1
# 9    2.1   4.7  44.9   0.5   1.6  31.6   0.7   0.9   70.2   1.6   3.1   51.6
# 10   1.8   5.2  35.3   0.7   2.4  26.9   0.8   1.0   78.8   1.2   2.8   42.7
# 11   1.6   4.0  40.9   1.0   2.9  34.1   0.3   0.5   65.2   0.7   1.1   58.3
# 12   1.1   2.1  52.5   0.3   0.8  30.8   0.6   0.6   89.7   0.9   1.3   66.1
# 13   1.2   1.8  67.7   0.1   0.1  66.7   0.3   0.4   75.0   1.2   1.7   67.7
# 14   1.1   2.0  54.5   0.3   0.5  50.0   0.2   0.2  100.0   0.8   1.5   56.3
# 15   1.0   2.1  45.5   0.3   0.9  31.6   0.1   0.1  100.0   0.7   1.2   56.0
# 16   0.8   2.5  30.0   0.5   2.3  22.2   0.0   0.0    0.0   0.3   0.3  100.0
# 17   0.7   1.0  66.7   0.3   0.7  50.0   0.0   0.0    0.0   0.3   0.3  100.0
# 18  41.6  85.1  48.9  11.6  31.5  36.8  17.6  22.6   77.9  30.0  53.6   56.0
#
#     SC-EFF  SH-EFF
# 0    1.371    0.57
# 1    1.320    0.54
# 2    1.352    0.57
# 3    1.551    0.65
# 4    1.209    0.52
# 5    1.262    0.56
# 6    1.218    0.51
# 7    1.384    0.58
# 8    1.500    0.73
# 9    1.144    0.50
# 10   0.988    0.42
# 11   1.152    0.53
# 12   1.426    0.58
# 13   1.569    0.69
# 14   1.318    0.61
# 15   1.091    0.52
# 16   0.800    0.40
# 17   1.667    0.83
# 18   1.321    0.56

# %%
df2 = dfFromURL('https://www.espn.com/nba/team/stats/_/name/cle', 1)
df2
# Out:
#                    Name
# 0   Donovan Mitchell SG
# 1     Darius Garland PG
# 2        Evan Mobley PF
# 3       Jarrett Allen C
# 4       Caris LeVert SG
# 5         Cedi Osman SF
# 6       Kevin Love PF *
# 7        Isaac Okoro SF
# 8       Danny Green F *
# 9       Lamar Stevens F
# 10       Ricky Rubio PG
# 11         Dean Wade PF
# 12         Raul Neto PG
# 13        Robin Lopez C
# 14      Isaiah Mobley F
# 15     Mamadi Diakite F
# 16       Sam Merrill SG
# 17     Dylan Windler SG
# 18                Total

# %%
pd.concat((df2, df1), axis=1)
# Out:
#                    Name   FGM   FGA   FG%   3PM   3PA   3P%   FTM   FTA  \
# 0   Donovan Mitchell SG  10.0  20.6  48.4   3.6   9.3  38.6   4.7   5.4
# 1     Darius Garland PG   7.6  16.4  46.2   2.4   6.0  41.0   4.0   4.7
# 2        Evan Mobley PF   6.7  12.1  55.5   0.3   1.3  21.6   2.6   3.9
# 3       Jarrett Allen C   6.0   9.3  64.5   0.0   0.1  11.1   2.4   3.3
# 4       Caris LeVert SG   4.3  10.0  43.1   1.7   4.4  39.2   1.8   2.4
# 5         Cedi Osman SF   3.1   6.9  45.2   1.5   4.1  37.3   1.0   1.4
# 6       Kevin Love PF *   2.7   7.0  38.9   1.7   4.8  35.4   1.4   1.5
# 7        Isaac Okoro SF   2.3   4.7  49.4   0.8   2.3  36.3   1.0   1.4
# 8       Danny Green F *   2.0   3.7  53.8   1.4   2.7  52.6   0.1   0.1
# 9       Lamar Stevens F   2.1   4.7  44.9   0.5   1.6  31.6   0.7   0.9
# 10       Ricky Rubio PG   1.8   5.2  35.3   0.7   2.4  26.9   0.8   1.0
# 11         Dean Wade PF   1.6   4.0  40.9   1.0   2.9  34.1   0.3   0.5
# 12         Raul Neto PG   1.1   2.1  52.5   0.3   0.8  30.8   0.6   0.6
# 13        Robin Lopez C   1.2   1.8  67.7   0.1   0.1  66.7   0.3   0.4
# 14      Isaiah Mobley F   1.1   2.0  54.5   0.3   0.5  50.0   0.2   0.2
# 15     Mamadi Diakite F   1.0   2.1  45.5   0.3   0.9  31.6   0.1   0.1
# 16       Sam Merrill SG   0.8   2.5  30.0   0.5   2.3  22.2   0.0   0.0
# 17     Dylan Windler SG   0.7   1.0  66.7   0.3   0.7  50.0   0.0   0.0
# 18                Total  41.6  85.1  48.9  11.6  31.5  36.8  17.6  22.6
#
#       FT%   2PM   2PA    2P%  SC-EFF  SH-EFF
# 0    86.7   6.4  11.3   56.6   1.371    0.57
# 1    86.3   5.1  10.4   49.2   1.320    0.54
# 2    67.4   6.4  10.7   59.7   1.352    0.57
# 3    73.3   6.0   9.1   65.3   1.551    0.65
# 4    72.2   2.6   5.6   46.2   1.209    0.52
# 5    69.5   1.6   2.8   56.5   1.262    0.56
# 6    88.9   1.0   2.2   46.7   1.218    0.51
# 7    75.7   1.5   2.4   61.7   1.384    0.58
# 8   100.0   0.6   1.0   57.1   1.500    0.73
# 9    70.2   1.6   3.1   51.6   1.144    0.50
# 10   78.8   1.2   2.8   42.7   0.988    0.42
# 11   65.2   0.7   1.1   58.3   1.152    0.53
# 12   89.7   0.9   1.3   66.1   1.426    0.58
# 13   75.0   1.2   1.7   67.7   1.569    0.69
# 14  100.0   0.8   1.5   56.3   1.318    0.61
# 15  100.0   0.7   1.2   56.0   1.091    0.52
# 16    0.0   0.3   0.3  100.0   0.800    0.40
# 17    0.0   0.3   0.3  100.0   1.667    0.83
# 18   77.9  30.0  53.6   56.0   1.321    0.56

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2023-04-09 01:44:54.171663

# %% [markdown]
# I have done reading this passage now. 2023-04-09 01:44:54.171663
